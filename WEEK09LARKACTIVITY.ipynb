# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1. Load the data into the pandas environment and identify some basic details of the dataset

# %%
df=pd.read_csv('employee.csv')
df
# Out:
#             name   age   income gender  department grade  performance_score
# 0    Allen Smith  45.0      NaN    NaN  Operations    G3                723
# 1        S Kumar   NaN  16000.0      F     Finance    G0                520
# 2    Jack Morgan  32.0  35000.0      M     Finance    G2                674
# 3      Ying Chin  45.0  65000.0      F       Sales    G3                556
# 4  Dheeraj Patel  30.0  42000.0      F  Operations    G2                711
# 5  Satyam Sharma   NaN  62000.0    NaN       Sales    G3                649
# 6   James Authur  54.0      NaN      F  Operations    G3                 53
# 7     Josh Wills  54.0  52000.0      F     Finance    G3                901
# 8       Leo Duck  23.0  98000.0      M       Sales    G4                709

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               9 non-null      object
#  1   age                7 non-null      float64
#  2   income             7 non-null      float64
#  3   gender             7 non-null      object
#  4   department         9 non-null      object
#  5   grade              9 non-null      object
#  6   performance_score  9 non-null      int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 632.0+ bytes

# %%
df.shape
# Out:
# (9, 7)

# %%
df.describe()
# Out:
#              age        income  performance_score
# count   7.000000      7.000000           9.000000
# mean   40.428571  52857.142857         610.666667
# std    12.204605  26028.372797         235.671912
# min    23.000000  16000.000000          53.000000
# 25%    31.000000  38500.000000         556.000000
# 50%    45.000000  52000.000000         674.000000
# 75%    49.500000  63500.000000         711.000000
# max    54.000000  98000.000000         901.000000

# %%
df.isnull().sum()
# Out:
# name                 0
# age                  2
# income               2
# gender               2
# department           0
# grade                0
# performance_score    0
# dtype: int64

# %%
plt.figure(figsize=(10,10))
plt.subplot(3,1,1)
sns.boxplot(df['age'])
plt.subplot(3,1,2)
sns.boxplot(df['income'])
plt.subplot(3,1,3)
sns.boxplot(df['performance_score'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
sns.barplot('income','performance_score',hue='gender',data=df)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='income', ylabel='performance_score'>

# %%
plt.figure(figsize=(20,10))
sns.barplot('department','income',hue='name',data=df)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='department', ylabel='income'>

# %% [markdown]
# Obsevations:
#
#
#     1.The given dataset includes the income and performance score of employee of various depalrtments in a company. Total 9 employee details are giveen
#     2.There are 6 missing values in dataset. 2 in age,2 in income and 2 in gender
#     3.The dataset includes details of 2 male, 4 female employee
#     4.Income increases with increase in performance score.
#     5.Income is large in sales department.

# %% [markdown]
# # 2. Reset the index as "name".

# %%
df=df.set_index('name')

# %%
df
# Out:
#                 age   income gender  department grade  performance_score
# name
# Allen Smith    45.0      NaN    NaN  Operations    G3                723
# S Kumar         NaN  16000.0      F     Finance    G0                520
# Jack Morgan    32.0  35000.0      M     Finance    G2                674
# Ying Chin      45.0  65000.0      F       Sales    G3                556
# Dheeraj Patel  30.0  42000.0      F  Operations    G2                711
# Satyam Sharma   NaN  62000.0    NaN       Sales    G3                649
# James Authur   54.0      NaN      F  Operations    G3                 53
# Josh Wills     54.0  52000.0      F     Finance    G3                901
# Leo Duck       23.0  98000.0      M       Sales    G4                709

# %% [markdown]
# # 3. Select rows for specific names Jack Morgan and Josh wills

# %%
df.loc[['Jack Morgan','Josh Wills'],:]
# Out:
#               age   income gender department grade  performance_score
# name
# Jack Morgan  32.0  35000.0      M    Finance    G2                674
# Josh Wills   54.0  52000.0      F    Finance    G3                901

# %% [markdown]
# # 4. Select data for multiple values "Sales" and “Finance”.

# %%
df[df['department'].isin(['Sales','Finance'])]
# Out:
#                 age   income gender department grade  performance_score
# name
# S Kumar         NaN  16000.0      F    Finance    G0                520
# Jack Morgan    32.0  35000.0      M    Finance    G2                674
# Ying Chin      45.0  65000.0      F      Sales    G3                556
# Satyam Sharma   NaN  62000.0    NaN      Sales    G3                649
# Josh Wills     54.0  52000.0      F    Finance    G3                901
# Leo Duck       23.0  98000.0      M      Sales    G4                709

# %% [markdown]
# # 5. Display employee who has more than 700 performance score.

# %%
df[df['performance_score']>700]
# Out:
#                 age   income gender  department grade  performance_score
# name
# Allen Smith    45.0      NaN    NaN  Operations    G3                723
# Dheeraj Patel  30.0  42000.0      F  Operations    G2                711
# Josh Wills     54.0  52000.0      F     Finance    G3                901
# Leo Duck       23.0  98000.0      M       Sales    G4                709

# %% [markdown]
# # 6. Display employee who has more than 500 and less than 700 performance score

# %%
m1 = df['performance_score']>500 
m2 =df['performance_score']<700
y= m1& m2
df[y]
# Out:
#                 age   income gender department grade  performance_score
# name
# S Kumar         NaN  16000.0      F    Finance    G0                520
# Jack Morgan    32.0  35000.0      M    Finance    G2                674
# Ying Chin      45.0  65000.0      F      Sales    G3                556
# Satyam Sharma   NaN  62000.0    NaN      Sales    G3                649

# %% [markdown]
# # 7. Check and handle missing values in the dataset.

# %%
df.isnull().sum()
# Out:
# age                  2
# income               2
# gender               2
# department           0
# grade                0
# performance_score    0
# dtype: int64

# %% [markdown]
#  THERE ARE 6 MISSING VALUES ARE IN THE DATA SET.  2 IN AGE, 2 IN INCOME AND 2 IN GENDER.

# %%
df['age']=df['age'].fillna(df['age'].median())
df
# Out:
#                 age   income gender  department grade  performance_score
# name
# Allen Smith    45.0      NaN    NaN  Operations    G3                723
# S Kumar        45.0  16000.0      F     Finance    G0                520
# Jack Morgan    32.0  35000.0      M     Finance    G2                674
# Ying Chin      45.0  65000.0      F       Sales    G3                556
# Dheeraj Patel  30.0  42000.0      F  Operations    G2                711
# Satyam Sharma  45.0  62000.0    NaN       Sales    G3                649
# James Authur   54.0      NaN      F  Operations    G3                 53
# Josh Wills     54.0  52000.0      F     Finance    G3                901
# Leo Duck       23.0  98000.0      M       Sales    G4                709

# %%
df['income'].mode()
# Out:
# 0    16000.0
# 1    35000.0
# 2    42000.0
# 3    52000.0
# 4    62000.0
# 5    65000.0
# 6    98000.0
# Name: income, dtype: float64

# %%
df['income']=df['income'].fillna(df['income'].mean())
df
# Out:
#                 age        income gender  department grade  performance_score
# name
# Allen Smith    45.0  52857.142857    NaN  Operations    G3                723
# S Kumar        45.0  16000.000000      F     Finance    G0                520
# Jack Morgan    32.0  35000.000000      M     Finance    G2                674
# Ying Chin      45.0  65000.000000      F       Sales    G3                556
# Dheeraj Patel  30.0  42000.000000      F  Operations    G2                711
# Satyam Sharma  45.0  62000.000000    NaN       Sales    G3                649
# James Authur   54.0  52857.142857      F  Operations    G3                 53
# Josh Wills     54.0  52000.000000      F     Finance    G3                901
# Leo Duck       23.0  98000.000000      M       Sales    G4                709

# %%
df['gender'].mode()
# Out:
# 0    F
# Name: gender, dtype: object

# %%
df['gender']=df['gender'].fillna(df['gender'].mode()[0])
df
# Out:
#                 age        income gender  department grade  performance_score
# name
# Allen Smith    45.0  52857.142857      F  Operations    G3                723
# S Kumar        45.0  16000.000000      F     Finance    G0                520
# Jack Morgan    32.0  35000.000000      M     Finance    G2                674
# Ying Chin      45.0  65000.000000      F       Sales    G3                556
# Dheeraj Patel  30.0  42000.000000      F  Operations    G2                711
# Satyam Sharma  45.0  62000.000000      F       Sales    G3                649
# James Authur   54.0  52857.142857      F  Operations    G3                 53
# Josh Wills     54.0  52000.000000      F     Finance    G3                901
# Leo Duck       23.0  98000.000000      M       Sales    G4                709

# %%
df.isnull().sum()
# Out:
# age                  0
# income               0
# gender               0
# department           0
# grade                0
# performance_score    0
# dtype: int64

# %% [markdown]
# # 8. Check the outliers and handle outliers in performance score using Percentiles.

# %%
plt.figure(figsize=(10,10))
#plt.subplot(3,1,1)
#sns.boxplot(df['age'])
#plt.subplot(3,1,2)
#sns.boxplot(df['income'])
#plt.subplot(3,1,3)
sns.boxplot(df['performance_score'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='performance_score'>

# %% [markdown]
# THERE ARE ONE OUTLIER IN PERFORMANCE_SCORE.

# %%
Q1=np.percentile(df['performance_score'],25,interpolation='midpoint')
Q2=np.percentile(df['performance_score'],50,interpolation='midpoint')
Q3=np.percentile(df['performance_score'],75,interpolation='midpoint')
print('Q1= ',Q1,'\n','Q2=',Q2)
IQR=Q3-Q1
print("IQR= ",IQR)
upp_limit=Q3+1.5*IQR
low_limit=Q1-1.5*IQR
print('UPPER LIMIT = ',upp_limit)
print('LOWER LIMIT = ',low_limit)
outlier=[]
for i in df['performance_score']:
    if((i>upp_limit) | (i<low_limit)):
        outlier.append(i)
print("outlier = ",outlier)
# Out:
# Q1=  556.0
#  Q2= 674.0
# IQR=  155.0
# UPPER LIMIT =  943.5
# LOWER LIMIT =  323.5
# outlier =  [53]

# %%
ind=(df['performance_score']<low_limit)
df.loc[ind].index
# Out:
# Index(['James Authur'], dtype='object', name='name')

# %%
df
# Out:
#                 age        income gender  department grade  performance_score
# name
# Allen Smith    45.0  52857.142857      F  Operations    G3                723
# S Kumar        45.0  16000.000000      F     Finance    G0                520
# Jack Morgan    32.0  35000.000000      M     Finance    G2                674
# Ying Chin      45.0  65000.000000      F       Sales    G3                556
# Dheeraj Patel  30.0  42000.000000      F  Operations    G2                711
# Satyam Sharma  45.0  62000.000000      F       Sales    G3                649
# James Authur   54.0  52857.142857      F  Operations    G3                 53
# Josh Wills     54.0  52000.000000      F     Finance    G3                901
# Leo Duck       23.0  98000.000000      M       Sales    G4                709

# %%
df.drop(['James Authur'],axis=0,inplace=True)
df
# Out:
#                 age        income gender  department grade  performance_score
# name
# Allen Smith    45.0  52857.142857      F  Operations    G3                723
# S Kumar        45.0  16000.000000      F     Finance    G0                520
# Jack Morgan    32.0  35000.000000      M     Finance    G2                674
# Ying Chin      45.0  65000.000000      F       Sales    G3                556
# Dheeraj Patel  30.0  42000.000000      F  Operations    G2                711
# Satyam Sharma  45.0  62000.000000      F       Sales    G3                649
# Josh Wills     54.0  52000.000000      F     Finance    G3                901
# Leo Duck       23.0  98000.000000      M       Sales    G4                709

# %% [markdown]
# # 9. Check the gender column and do Dummy encoding.

# %%
df['gender']=pd.get_dummies(df['gender'], drop_first=1)

# %%
df
# Out:
#                 age        income  gender  department grade  performance_score
# name
# Allen Smith    45.0  52857.142857       0  Operations    G3                723
# S Kumar        45.0  16000.000000       0     Finance    G0                520
# Jack Morgan    32.0  35000.000000       1     Finance    G2                674
# Ying Chin      45.0  65000.000000       0       Sales    G3                556
# Dheeraj Patel  30.0  42000.000000       0  Operations    G2                711
# Satyam Sharma  45.0  62000.000000       0       Sales    G3                649
# Josh Wills     54.0  52000.000000       0     Finance    G3                901
# Leo Duck       23.0  98000.000000       1       Sales    G4                709

# %% [markdown]
# # 10.Do the standard scaling on the feature performance score.

# %%
df.describe()
# Out:
#              age        income   gender  performance_score
# count   8.000000      8.000000  8.00000            8.00000
# mean   39.875000  52857.142857  0.25000          680.37500
# std    10.343217  24097.590700  0.46291          116.16729
# min    23.000000  16000.000000  0.00000          520.00000
# 25%    31.500000  40250.000000  0.00000          625.75000
# 50%    45.000000  52428.571429  0.00000          691.50000
# 75%    45.000000  62750.000000  0.25000          714.00000
# max    54.000000  98000.000000  1.00000          901.00000

# %%
from sklearn import preprocessing
sc=preprocessing.StandardScaler()
#x=df['performance_score']
df['performance_score']=sc.fit_transform(df[['performance_score']])

# %%
df.describe()
# Out:
#              age        income   gender  performance_score
# count   8.000000      8.000000  8.00000       8.000000e+00
# mean   39.875000  52857.142857  0.25000       4.857226e-17
# std    10.343217  24097.590700  0.46291       1.069045e+00
# min    23.000000  16000.000000  0.00000      -1.475872e+00
# 25%    31.500000  40250.000000  0.00000      -5.026938e-01
# 50%    45.000000  52428.571429  0.00000       1.023793e-01
# 75%    45.000000  62750.000000  0.25000       3.094385e-01
# max    54.000000  98000.000000  1.00000       2.030331e+00
